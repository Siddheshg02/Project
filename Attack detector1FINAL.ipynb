# %%
import numpy as np

# %%
import pandas as pd

# %%
# List of file names for the 9 devices
file_names = [
    '1.benign.csv', 
              '1.gafgyt.combo.csv', '1.gafgyt.junk.csv', '1.gafgyt.scan.csv','1.gafgyt.tcp.csv','1.gafgyt.udp.csv', 
              '1.mirai.ack.csv', '1.mirai.syn.csv','1.mirai.scan.csv','1.mirai.udp.csv','1.mirai.udpplain.csv'
             ,'2.benign.csv', 
              '2.gafgyt.combo.csv', '2.gafgyt.junk.csv', '2.gafgyt.scan.csv','2.gafgyt.tcp.csv','2.gafgyt.udp.csv', 
              '2.mirai.ack.csv', '2.mirai.syn.csv','2.mirai.scan.csv','2.mirai.udp.csv','2.mirai.udpplain.csv'
             ,'3.benign.csv', 
              '3.gafgyt.combo.csv', '3.gafgyt.junk.csv', '3.gafgyt.scan.csv','3.gafgyt.tcp.csv','3.gafgyt.udp.csv' 
              
             ,'4.benign.csv', 
              '4.gafgyt.combo.csv', '4.gafgyt.junk.csv', '4.gafgyt.scan.csv','4.gafgyt.tcp.csv','4.gafgyt.udp.csv', 
              '4.mirai.ack.csv', '4.mirai.syn.csv','4.mirai.scan.csv','4.mirai.udp.csv','4.mirai.udpplain.csv'
             ,'5.benign.csv', 
              '5.gafgyt.combo.csv', '5.gafgyt.junk.csv', '5.gafgyt.scan.csv','5.gafgyt.tcp.csv','5.gafgyt.udp.csv', 
              '5.mirai.ack.csv', '5.mirai.syn.csv','5.mirai.scan.csv','5.mirai.udp.csv','5.mirai.udpplain.csv'
             ,'6.benign.csv', 
              '6.gafgyt.combo.csv', '6.gafgyt.junk.csv', '6.gafgyt.scan.csv','6.gafgyt.tcp.csv','6.gafgyt.udp.csv', 
              '6.mirai.ack.csv', '6.mirai.syn.csv','6.mirai.scan.csv','6.mirai.udp.csv','6.mirai.udpplain.csv'
             ,'7.benign.csv', 
              '7.gafgyt.combo.csv', '7.gafgyt.junk.csv', '7.gafgyt.scan.csv','7.gafgyt.tcp.csv','7.gafgyt.udp.csv' 
              
             ,'8.benign.csv', 
              '8.gafgyt.combo.csv', '8.gafgyt.junk.csv', '8.gafgyt.scan.csv','8.gafgyt.tcp.csv','8.gafgyt.udp.csv', 
              '8.mirai.ack.csv', '8.mirai.syn.csv','8.mirai.scan.csv','8.mirai.udp.csv','8.mirai.udpplain.csv'
             ,'9.benign.csv', 
              '9.gafgyt.combo.csv', '9.gafgyt.junk.csv', '9.gafgyt.scan.csv','9.gafgyt.tcp.csv','9.gafgyt.udp.csv', 
              '9.mirai.ack.csv', '9.mirai.syn.csv','9.mirai.scan.csv','9.mirai.udp.csv','9.mirai.udpplain.csv'
]

# Create an empty list to store the dataframes for each device
device_dataframes = []

# Loop through the file names and load, sample, and label the data for each device
for file_name in file_names:
    df = pd.read_csv(file_name)
    df = df.sample(frac=0.25, replace=False)
    
    # Add a 'type' column to label the data
    device_name = file_name.split('.')[1]  # Extract the device name from the file name
    df['type'] = device_name
    
    # Append the dataframe to the list
    device_dataframes.append(df)

# Concatenate the dataframes into a single dataframe
data = pd.concat(device_dataframes, axis=0, sort=False, ignore_index=True)

# Now, 'data' contains the combined and labeled data for all 9 devices

# %%
data
# Out:
#          MI_dir_L5_weight  MI_dir_L5_mean  MI_dir_L5_variance  \
# 0                3.841775      100.958815            3.080675
# 1                1.000000       98.000000            0.000000
# 2                1.000027       97.998975            0.038958
# 3                5.111421      100.794938           49.160449
# 4                1.000000      102.000000            0.000000
# ...                   ...             ...                 ...
# 1765642         83.056427      478.317052        31659.467828
# 1765643        132.802322      316.801466        60869.197523
# 1765644         92.772473      303.616151        60997.549567
# 1765645        329.990771      492.031343        26772.402000
# 1765646        117.744321      494.321390        25919.697006
#
#          MI_dir_L3_weight  MI_dir_L3_mean  MI_dir_L3_variance  \
# 0                4.562388      101.123266            2.738273
# 1                1.000000       98.000000            0.000000
# 2                1.001814       97.931195            2.609913
# 3                5.395748       98.754137          125.790451
# 4                1.000000      102.000000            0.000000
# ...                   ...             ...                 ...
# 1765642        140.063881      430.989346        45635.642092
# 1765643        204.023679      346.915577        59367.090119
# 1765644        167.839395      318.300586        60881.296760
# 1765645        378.899843      489.779917        27600.501948
# 1765646        196.683552      456.270958        38727.175405
#
#          MI_dir_L1_weight  MI_dir_L1_mean  MI_dir_L1_variance  \
# 0                5.465741      101.268169            2.391757
# 1                1.000001       97.999961            0.001534
# 2                1.140907       94.004392          138.658407
# 3                6.196599       93.950646          272.843307
# 4                1.000000      101.999994            0.000231
# ...                   ...             ...                 ...
# 1765642        468.610118      399.802759        52396.487794
# 1765643        494.014328      376.987186        56068.797129
# 1765644        556.940615      380.552791        55598.979412
# 1765645        674.220670      458.610425        38023.279150
# 1765646        607.968588      426.935789        46623.435890
#
#          MI_dir_L0.1_weight  ...  HpHp_L0.1_covariance  HpHp_L0.1_pcc  \
# 0                  6.718141  ...          9.550000e-43            0.0
# 1                  2.612679  ...         -9.880000e-43            0.0
# 2                  5.099402  ...         -3.640000e-48            0.0
# 3                  8.136787  ...         -5.060000e-34            0.0
# 4                  1.830793  ...          4.720000e-68            0.0
# ...                     ...  ...                   ...            ...
# 1765642         5608.707646  ...          0.000000e+00            0.0
# 1765643         4050.977878  ...          0.000000e+00            0.0
# 1765644         5694.893926  ...          0.000000e+00            0.0
# 1765645         5394.264133  ...          0.000000e+00            0.0
# 1765646         5774.513307  ...          0.000000e+00            0.0
#
#          HpHp_L0.01_weight  HpHp_L0.01_mean  HpHp_L0.01_std  \
# 0                 5.287905             98.0        0.000001
# 1                 5.308261             98.0        0.000001
# 2                 5.309329             98.0        0.000001
# 3                 4.152702            102.0        0.000002
# 4                 4.218867            102.0        0.000001
# ...                    ...              ...             ...
# 1765642       25667.253844            554.0        0.000057
# 1765643        7680.158356            554.0        0.000042
# 1765644       26159.084463            554.0        0.000061
# 1765645           1.000000             60.0        0.000000
# 1765646       25497.870076            554.0        0.000055
#
#          HpHp_L0.01_magnitude  HpHp_L0.01_radius  HpHp_L0.01_covariance  \
# 0                  138.592929       1.820000e-12          -4.590000e-29
# 1                  138.592929       4.070000e-12           1.390000e-28
# 2                  138.592929       4.070000e-12           3.450000e-28
# 3                  144.249783       6.560000e-12          -1.950000e-28
# 4                  144.249783       5.750000e-12           4.280000e-28
# ...                       ...                ...                    ...
# 1765642            554.000000       3.259629e-09           0.000000e+00
# 1765643            554.000000       1.804437e-09           0.000000e+00
# 1765644            554.000000       3.667083e-09           0.000000e+00
# 1765645             60.000000       0.000000e+00           0.000000e+00
# 1765646            554.000000       3.026798e-09           0.000000e+00
#
#          HpHp_L0.01_pcc    type
# 0          0.000000e+00  benign
# 1          5.410000e-17  benign
# 2          1.340000e-16  benign
# 3         -4.380000e-17  benign
# 4          1.360000e-16  benign
# ...                 ...     ...
# 1765642    0.000000e+00   mirai
# 1765643    0.000000e+00   mirai
# 1765644    0.000000e+00   mirai
# 1765645    0.000000e+00   mirai
# 1765646    0.000000e+00   mirai
#
# [1765647 rows x 116 columns]

# %%
data.groupby('type')['type'].count()
# Out:
# type
# benign    138982
# gafgyt    709567
# mirai     917098
# Name: type, dtype: int64

# %%
sampler=np.random.permutation(len(data))
data=data.take(sampler)
data.head()
# Out:
#          MI_dir_L5_weight  MI_dir_L5_mean  MI_dir_L5_variance  \
# 1595429          1.000000       60.000000            0.000000
# 118530         117.458208       70.140855           39.135029
# 1355406        160.596834       74.005789            0.138908
# 1408361          1.000000       60.000000            0.000000
# 908566           1.000000       60.000000            0.000000
#
#          MI_dir_L3_weight  MI_dir_L3_mean  MI_dir_L3_variance  \
# 1595429          1.000000       60.000000            0.000000
# 118530         208.812834       69.468641           42.905850
# 1355406        270.646505       74.014056            0.337844
# 1408361          1.000000       60.000000            0.000000
# 908566           1.000000       60.000000            0.000000
#
#          MI_dir_L1_weight  MI_dir_L1_mean  MI_dir_L1_variance  \
# 1595429          1.000000       60.000000            0.000000
# 118530         651.128884       69.227037           44.082587
# 1355406        802.028518       74.035794            2.888211
# 1408361          1.000000       60.000000            0.000000
# 908566           1.000000       60.000000            0.000000
#
#          MI_dir_L0.1_weight  ...  HpHp_L0.1_covariance  HpHp_L0.1_pcc  \
# 1595429            1.000000  ...                   0.0            0.0
# 118530          6619.581044  ...                   0.0            0.0
# 1355406         7649.340447  ...                   0.0            0.0
# 1408361            1.000000  ...                   0.0            0.0
# 908566             1.000000  ...                   0.0            0.0
#
#          HpHp_L0.01_weight  HpHp_L0.01_mean  HpHp_L0.01_std  \
# 1595429           1.000000             60.0        0.000000
# 118530            1.000000             74.0        0.000000
# 1355406           1.682538             74.0        0.000001
# 1408361           1.000000             60.0        0.000000
# 908566            1.000000             60.0        0.000000
#
#          HpHp_L0.01_magnitude  HpHp_L0.01_radius  HpHp_L0.01_covariance  \
# 1595429             60.000000       0.000000e+00                    0.0
# 118530              74.000000       0.000000e+00                    0.0
# 1355406             95.268043       1.818989e-12                    0.0
# 1408361             60.000000       0.000000e+00                    0.0
# 908566              60.000000       0.000000e+00                    0.0
#
#          HpHp_L0.01_pcc    type
# 1595429             0.0  gafgyt
# 118530              0.0   mirai
# 1355406             0.0  gafgyt
# 1408361             0.0  gafgyt
# 908566              0.0  gafgyt
#
# [5 rows x 116 columns]

# %%
labels_full=pd.get_dummies(data['type'], prefix='type')
labels_full
# Out:
#          type_benign  type_gafgyt  type_mirai
# 1595429            0            1           0
# 118530             0            0           1
# 1355406            0            1           0
# 1408361            0            1           0
# 908566             0            1           0
# ...              ...          ...         ...
# 1152504            0            0           1
# 634923             0            1           0
# 1066838            0            1           0
# 779398             0            0           1
# 1194974            0            0           1
#
# [1765647 rows x 3 columns]

# %%
#drop labels from training dataset
data=data.drop(columns='type')
data.head()
# Out:
#          MI_dir_L5_weight  MI_dir_L5_mean  MI_dir_L5_variance  \
# 1595429          1.000000       60.000000            0.000000
# 118530         117.458208       70.140855           39.135029
# 1355406        160.596834       74.005789            0.138908
# 1408361          1.000000       60.000000            0.000000
# 908566           1.000000       60.000000            0.000000
#
#          MI_dir_L3_weight  MI_dir_L3_mean  MI_dir_L3_variance  \
# 1595429          1.000000       60.000000            0.000000
# 118530         208.812834       69.468641           42.905850
# 1355406        270.646505       74.014056            0.337844
# 1408361          1.000000       60.000000            0.000000
# 908566           1.000000       60.000000            0.000000
#
#          MI_dir_L1_weight  MI_dir_L1_mean  MI_dir_L1_variance  \
# 1595429          1.000000       60.000000            0.000000
# 118530         651.128884       69.227037           44.082587
# 1355406        802.028518       74.035794            2.888211
# 1408361          1.000000       60.000000            0.000000
# 908566           1.000000       60.000000            0.000000
#
#          MI_dir_L0.1_weight  ...  HpHp_L0.1_radius  HpHp_L0.1_covariance  \
# 1595429            1.000000  ...               0.0                   0.0
# 118530          6619.581044  ...               0.0                   0.0
# 1355406         7649.340447  ...               0.0                   0.0
# 1408361            1.000000  ...               0.0                   0.0
# 908566             1.000000  ...               0.0                   0.0
#
#          HpHp_L0.1_pcc  HpHp_L0.01_weight  HpHp_L0.01_mean  HpHp_L0.01_std  \
# 1595429            0.0           1.000000             60.0        0.000000
# 118530             0.0           1.000000             74.0        0.000000
# 1355406            0.0           1.682538             74.0        0.000001
# 1408361            0.0           1.000000             60.0        0.000000
# 908566             0.0           1.000000             60.0        0.000000
#
#          HpHp_L0.01_magnitude  HpHp_L0.01_radius  HpHp_L0.01_covariance  \
# 1595429             60.000000       0.000000e+00                    0.0
# 118530              74.000000       0.000000e+00                    0.0
# 1355406             95.268043       1.818989e-12                    0.0
# 1408361             60.000000       0.000000e+00                    0.0
# 908566              60.000000       0.000000e+00                    0.0
#
#          HpHp_L0.01_pcc
# 1595429             0.0
# 118530              0.0
# 1355406             0.0
# 1408361             0.0
# 908566              0.0
#
# [5 rows x 115 columns]

# %%
#standardize numerical columns
def standardize(df,col):
    df[col]= (df[col]-df[col].mean())/df[col].std()

data_st=data.copy()
for i in (data_st.iloc[:,:-1].columns):
    standardize (data_st,i)

data_st.head()
# Out:
#          MI_dir_L5_weight  MI_dir_L5_mean  MI_dir_L5_variance  \
# 1595429         -1.170184       -0.718145           -0.640975
# 118530           0.519008       -0.656814           -0.639351
# 1355406          1.144721       -0.633439           -0.640969
# 1408361         -1.170184       -0.718145           -0.640975
# 908566          -1.170184       -0.718145           -0.640975
#
#          MI_dir_L3_weight  MI_dir_L3_mean  MI_dir_L3_variance  \
# 1595429         -1.172348       -0.741979           -0.680524
# 118530           0.727658       -0.682854           -0.678820
# 1355406          1.292996       -0.654471           -0.680510
# 1408361         -1.172348       -0.741979           -0.680524
# 908566          -1.172348       -0.741979           -0.680524
#
#          MI_dir_L1_weight  MI_dir_L1_mean  MI_dir_L1_variance  \
# 1595429         -1.170683       -0.765056           -0.712119
# 118530           0.908102       -0.705768           -0.710430
# 1355406          1.390602       -0.674869           -0.712008
# 1408361         -1.170683       -0.765056           -0.712119
# 908566          -1.170683       -0.765056           -0.712119
#
#          MI_dir_L0.1_weight  ...  HpHp_L0.1_radius  HpHp_L0.1_covariance  \
# 1595429           -1.173439  ...         -0.062464             -0.044584
# 118530             1.111007  ...         -0.062464             -0.044584
# 1355406            1.466435  ...         -0.062464             -0.044584
# 1408361           -1.173439  ...         -0.062464             -0.044584
# 908566            -1.173439  ...         -0.062464             -0.044584
#
#          HpHp_L0.1_pcc  HpHp_L0.01_weight  HpHp_L0.01_mean  HpHp_L0.01_std  \
# 1595429      -0.033917          -0.197247        -0.578528       -0.104789
# 118530       -0.033917          -0.197247        -0.510600       -0.104789
# 1355406      -0.033917          -0.197073        -0.510600       -0.104789
# 1408361      -0.033917          -0.197247        -0.578528       -0.104789
# 908566       -0.033917          -0.197247        -0.578528       -0.104789
#
#          HpHp_L0.01_magnitude  HpHp_L0.01_radius  HpHp_L0.01_covariance  \
# 1595429             -0.599154          -0.069754               -0.04093
# 118530              -0.531656          -0.069754               -0.04093
# 1355406             -0.429117          -0.069754               -0.04093
# 1408361             -0.599154          -0.069754               -0.04093
# 908566              -0.599154          -0.069754               -0.04093
#
#          HpHp_L0.01_pcc
# 1595429             0.0
# 118530              0.0
# 1355406             0.0
# 1408361             0.0
# 908566              0.0
#
# [5 rows x 115 columns]

# %%
#training data for the neural net
train_data_st=data_st.values
train_data_st
# Out:
# array([[-1.17018406, -0.71814462, -0.64097453, ..., -0.06975444,
#         -0.04093006,  0.        ],
#        [ 0.5190076 , -0.65681401, -0.63935058, ..., -0.06975444,
#         -0.04093006,  0.        ],
#        [ 1.14472054, -0.63343937, -0.64096877, ..., -0.06975444,
#         -0.04093006,  0.        ],
#        ...,
#        [ 1.12987255, -0.6334347 , -0.640968  , ..., -0.06975444,
#         -0.04093006,  0.        ],
#        [ 1.25019213,  0.23842937,  1.5630584 , ..., -0.06975444,
#         -0.04093006,  0.        ],
#        [ 0.24554833,  1.64306536,  1.03710884, ..., -0.06975444,
#         -0.04093006,  0.        ]])

# %%
#labels for training
labels=labels_full.values
labels
# Out:
# array([[0, 1, 0],
#        [0, 0, 1],
#        [0, 1, 0],
#        ...,
#        [0, 1, 0],
#        [0, 0, 1],
#        [0, 0, 1]], dtype=uint8)

# %% [markdown]
# # LSTM

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from sklearn.model_selection import train_test_split

# Splitting data into train and test sets
x_train, x_test, y_train, y_test = train_test_split(train_data_st, labels, test_size=0.2, random_state=42)

# Define the LSTM model
lstm_model = Sequential()
lstm_model.add(LSTM(32, input_shape=(x_train.shape[1], 1), return_sequences=True))
lstm_model.add(Dropout(0.2))
lstm_model.add(LSTM(64, return_sequences=True))
lstm_model.add(Dropout(0.2))
lstm_model.add(LSTM(32))
lstm_model.add(Dropout(0.2))
lstm_model.add(Dense(labels.shape[1], activation='softmax'))

# Compile the model
lstm_model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# Display model summary
lstm_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 115, 32)           4352
#
#  dropout (Dropout)           (None, 115, 32)           0
#
#  lstm_1 (LSTM)               (None, 115, 64)           24832
#
#  dropout_1 (Dropout)         (None, 115, 64)           0
#
#  lstm_2 (LSTM)               (None, 32)                12416
#
#  dropout_2 (Dropout)         (None, 32)                0
#
#  dense (Dense)               (None, 3)                 99
#
# =================================================================
# Total params: 41,699
# Trainable params: 41,699
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Set up callbacks
model_checkpoint = ModelCheckpoint('lstm_model_checkpoint.h5', monitor='val_loss', save_best_only=True)
early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

# Train the LSTM model
history = lstm_model.fit(x_train, y_train, validation_data=(x_test, y_test),
                         epochs=10, batch_size=32, callbacks=[early_stopping, model_checkpoint])

# Save the trained model
lstm_model.save('lstm_model.h5')

lstm_model.save('G:\SIDDHESH\College Data\BE Sem1\Project\lstm_model_final.h5')

# %%
lstm_model.load_weights('lstm_model_checkpoint.h5')

# %%
test_loss, test_accuracy = lstm_model.evaluate(x_test, y_test)
print(f"Test Loss: {test_loss}, Test Accuracy: {test_accuracy}")
# Out:
# 11036/11036 [==============================] - 475s 43ms/step - loss: 0.0211 - accuracy: 0.9991
# Test Loss: 0.02113368920981884, Test Accuracy: 0.9990909695625305

# %% [markdown]
# # PNN

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.callbacks import ModelCheckpoint

x_train, x_test, y_train, y_test = train_test_split(
    train_data_st, labels, test_size=0.25, random_state=42)

# Function to create a progressive neural network model
def create_progressive_nn(input_size, output_size):
    model = Sequential()
    model.add(Dense(64, input_dim=input_size, activation='relu'))
    model.add(Dense(128, activation='relu'))
    model.add(Dense(output_size, activation='softmax'))
    model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
    return model

# %%
# Train a progressive neural network on the data
progressive_nn = create_progressive_nn(train_data_st.shape[1], labels.shape[1])

model_checkpoint = ModelCheckpoint('Pnn_model_checkpoint.h5', 
                                   monitor='val_loss', 
                                   save_best_only=True)

#monitor = EarlyStopping(monitor='val_loss', min_delta=1e-3, patience=5, verbose=1, mode='auto')

# %%
progressive_nn.fit(x_train, y_train, validation_data=(x_test, y_test),
                   verbose=2, epochs=10 , callbacks=[model_checkpoint])

# %%
progressive_nn.save('Pnn_model_final.h5')

test_loss, test_accuracy =progressive_nn.evaluate(x_test, y_test)
print(f"Test Loss: {test_loss}, Test Accuracy: {test_accuracy}")
# Out:
# 2024-02-28 13:24:04.924083: W tensorflow/core/framework/cpu_allocator_impl.cc:82] Allocation of 203049520 exceeds 10% of free system memory.
# 13795/13795 [==============================] - 6s 432us/step - loss: 1.2239 - accuracy: 0.3868
# Test Loss: 1.2238919734954834, Test Accuracy: 0.38679736852645874

# %%
progressive_nn.load_weights('Pnn_model_checkpoint.h5')

# %%
test_loss, test_accuracy = progressive_nn.evaluate(x_test, y_test)
print(f"Test Loss: {test_loss}, Test Accuracy: {test_accuracy}")
# Out:
# 11036/11036 [==============================] - 17s 2ms/step - loss: 325.7365 - accuracy: 0.6086
# Test Loss: 325.7364807128906, Test Accuracy: 0.6086426973342896

# %% [markdown]
# # DNN

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, BatchNormalization, Dropout
from tensorflow.keras.callbacks import ModelCheckpoint
from sklearn.model_selection import train_test_split

# Split the data into training and testing sets
x_train, x_test, y_train, y_test = train_test_split(train_data_st, labels, test_size=0.2, random_state=42)

# Create a deep neural network model
model = Sequential()

# Input layer
model.add(Dense(128, input_dim=train_data_st.shape[1], activation='relu'))
model.add(BatchNormalization())
model.add(Dropout(0.5))

# Hidden layers
model.add(Dense(256, activation='relu'))
model.add(BatchNormalization())
model.add(Dropout(0.5))

model.add(Dense(128, activation='relu'))
model.add(BatchNormalization())
model.add(Dropout(0.5))

# Output layer
model.add(Dense(labels.shape[1], activation='softmax'))

# Compile the model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Display model summary
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_4 (Dense)             (None, 128)               14848
#
#  batch_normalization (BatchN  (None, 128)              512
#  ormalization)
#
#  dropout_3 (Dropout)         (None, 128)               0
#
#  dense_5 (Dense)             (None, 256)               33024
#
#  batch_normalization_1 (Batc  (None, 256)              1024
#  hNormalization)
#
#  dropout_4 (Dropout)         (None, 256)               0
#
#  dense_6 (Dense)             (None, 128)               32896
#
#  batch_normalization_2 (Batc  (None, 128)              512
#  hNormalization)
#
#  dropout_5 (Dropout)         (None, 128)               0
#
#  dense_7 (Dense)             (None, 3)                 387
#
# =================================================================
# Total params: 83,203
# Trainable params: 82,179
# Non-trainable params: 1,024
# _________________________________________________________________

# %%
# Set up ModelCheckpoint callback to save model weights during training
model_checkpoint = ModelCheckpoint('dnn_model_checkpoint.h5', monitor='val_loss', save_best_only=True)

# Train the model
history = model.fit(x_train, y_train, validation_data=(x_test, y_test), epochs=10, batch_size=32, callbacks=[model_checkpoint])

# %%
model.load_weights('dnn_model_checkpoint.h5')

# %%
# Evaluate the model on the test set
test_loss, test_accuracy = model.evaluate(x_test, y_test)
print(f"Test Loss: {test_loss}, Test Accuracy: {test_accuracy}")
# Out:
# 11036/11036 [==============================] - 23s 2ms/step - loss: 0.0018 - accuracy: 0.9997
# Test Loss: 0.001811073161661625, Test Accuracy: 0.9996601939201355

# %% [markdown]
# # DNN-PNN

# %%
dnn_output = model.layers[-1].output
pnn_output = progressive_nn.layers[-1].output

# %%
from tensorflow.keras.layers import concatenate


# Concatenate the output tensors along a new axis
combined_output = concatenate([dnn_output, pnn_output])

# Add additional layers to process the combined output
combined_output = Dense(128, activation='relu')(combined_output)
combined_output = BatchNormalization()(combined_output)
combined_output = Dropout(0.5)(combined_output)
combined_output = Dense(labels.shape[1], activation='softmax')(combined_output)

# Create the combined model
combined_model = tf.keras.Model(inputs=[model.input, progressive_nn.input], outputs=combined_output)

# Compile the combined model
combined_model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Display model summary
combined_model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  dense_4_input (InputLayer)     [(None, 115)]        0           []
#
#  dense_4 (Dense)                (None, 128)          14848       ['dense_4_input[0][0]']
#
#  batch_normalization (BatchNorm  (None, 128)         512         ['dense_4[0][0]']
#  alization)
#
#  dropout_3 (Dropout)            (None, 128)          0           ['batch_normalization[0][0]']
#
#  dense_5 (Dense)                (None, 256)          33024       ['dropout_3[0][0]']
#
#  batch_normalization_1 (BatchNo  (None, 256)         1024        ['dense_5[0][0]']
#  rmalization)
#
#  dropout_4 (Dropout)            (None, 256)          0           ['batch_normalization_1[0][0]']
#
#  dense_6 (Dense)                (None, 128)          32896       ['dropout_4[0][0]']
#
#  dense_1_input (InputLayer)     [(None, 115)]        0           []
#
#  batch_normalization_2 (BatchNo  (None, 128)         512         ['dense_6[0][0]']
#  rmalization)
#
#  dense_1 (Dense)                (None, 64)           7424        ['dense_1_input[0][0]']
#
#  dropout_5 (Dropout)            (None, 128)          0           ['batch_normalization_2[0][0]']
#
#  dense_2 (Dense)                (None, 128)          8320        ['dense_1[0][0]']
#
#  dense_7 (Dense)                (None, 3)            387         ['dropout_5[0][0]']
#
#  dense_3 (Dense)                (None, 3)            387         ['dense_2[0][0]']
#
#  concatenate (Concatenate)      (None, 6)            0           ['dense_7[0][0]',
#                                                                   'dense_3[0][0]']
#
#  dense_8 (Dense)                (None, 128)          896         ['concatenate[0][0]']
#
#  batch_normalization_3 (BatchNo  (None, 128)         512         ['dense_8[0][0]']
#  rmalization)
#
#  dropout_6 (Dropout)            (None, 128)          0           ['batch_normalization_3[0][0]']
#
#  dense_9 (Dense)                (None, 3)            387         ['dropout_6[0][0]']
#
# ==================================================================================================
# Total params: 101,129
# Trainable params: 99,849
# Non-trainable params: 1,280
# __________________________________________________________________________________________________

# %%
# Set up ModelCheckpoint callback to save model weights during training
model_checkpoint = ModelCheckpoint('hybrid_model_checkpoint.h5', monitor='val_loss', save_best_only=True)

# Train the combined model
history = combined_model.fit([x_train, x_train], y_train, validation_data=([x_test, x_test], y_test), epochs=10, batch_size=32, callbacks=[model_checkpoint])

# %%
test_loss, test_accuracy = combined_model.evaluate([x_test, x_test], y_test)
print(f"Test Loss: {test_loss}, Test Accuracy: {test_accuracy}")

# %%
combined_model.save('hybrid_model_final.h5')

# %%
combined_model.load_weights('hybrid_model_checkpoint.h5')

# %%
test_loss, test_accuracy = combined_model.evaluate([x_test, x_test], y_test)
print(f"Test Loss: {test_loss}, Test Accuracy: {test_accuracy}")
# Out:
# 2024-02-28 13:24:56.118750: W tensorflow/core/framework/cpu_allocator_impl.cc:82] Allocation of 162439800 exceeds 10% of free system memory.
# 2024-02-28 13:24:56.209417: W tensorflow/core/framework/cpu_allocator_impl.cc:82] Allocation of 162439800 exceeds 10% of free system memory.
# 11036/11036 [==============================] - 12s 1ms/step - loss: 0.0022 - accuracy: 0.9996
# Test Loss: 0.002198115224018693, Test Accuracy: 0.999612033367157

# %%
from sklearn.metrics import precision_score, recall_score, f1_score , confusion_matrix


y_pred = combined_model.predict([x_test, x_test])

# Convert one-hot encoded predictions and true labels to class labels
y_pred_classes = np.argmax(y_pred, axis=1)
y_true_classes = np.argmax(y_test, axis=1)

# Calculate precision, recall, and F1 score
precision = precision_score(y_true_classes, y_pred_classes, average='weighted')
recall = recall_score(y_true_classes, y_pred_classes, average='weighted')
f1 = f1_score(y_true_classes, y_pred_classes, average='weighted')
conf_matrix = confusion_matrix(y_true_classes, y_pred_classes)

print(f"Precision: {precision}")
print(f"Recall: {recall}")
print(f"F1 Score: {f1}")
print(conf_matrix)
# Out:
# 2024-02-28 13:25:25.473246: W tensorflow/core/framework/cpu_allocator_impl.cc:82] Allocation of 162439800 exceeds 10% of free system memory.
# 2024-02-28 13:25:25.561567: W tensorflow/core/framework/cpu_allocator_impl.cc:82] Allocation of 162439800 exceeds 10% of free system memory.
# Precision: 0.9996124827532105
# Recall: 0.9996120408914564
# F1 Score: 0.9996121757016008
# [[ 27923     25      1]
#  [    70 141487      2]
#  [    12     27 183583]]

# %%
from sklearn.preprocessing import label_binarize
from sklearn.metrics import roc_curve, auc
import numpy as np
import matplotlib.pyplot as plt

# Assuming you have your predictions (y_pred) and true labels (y_test) defined

# Convert true labels to one-hot encoded format
y_true_one_hot = label_binarize(y_true_classes, classes=np.unique(y_true_classes))

# Convert one-hot encoded predictions to class scores (probabilities)
y_pred_scores = y_pred

# Compute ROC curve and ROC area for each class
fpr = dict()
tpr = dict()
roc_auc = dict()

n_classes = y_true_one_hot.shape[1]

for i in range(n_classes):
    fpr[i], tpr[i], _ = roc_curve(y_true_one_hot[:, i], y_pred_scores[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

# Calculate the grand average AUC
all_fpr = np.unique(np.concatenate([fpr[i] for i in range(n_classes)]))
mean_tpr = np.zeros_like(all_fpr)

for i in range(n_classes):
    mean_tpr += np.interp(all_fpr, fpr[i], tpr[i])

mean_tpr /= n_classes

roc_auc["grand_mean"] = auc(all_fpr, mean_tpr)

# Plot ROC curve for each class
plt.figure(figsize=(10, 6))
colors = ['blue', 'orange', 'green', 'red', 'purple', 'brown', 'pink', 'gray', 'olive']
for i, color in zip(range(n_classes), colors):
    plt.plot(fpr[i], tpr[i], color=color, lw=2, label=f'Class {i} (AUC = {roc_auc[i]:.2f})')

# Plot ideal performance AUC (diagonal line)
plt.plot([0, 1], [0, 1], color='gray', linestyle='--', lw=2, label='Ideal Performance (AUC = 0.50)')

# Plot grand average AUC
plt.plot(all_fpr, mean_tpr, color='black', linestyle='--', lw=2, label=f'Grand Mean (AUC = {roc_auc["grand_mean"]:.2f})')

plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve for Multiclass')
plt.legend(loc='lower right')
plt.show()

# %% [markdown]
# # LSTM-DNN

# %%
dnn_output = model.layers[-1].output
lstm_output = lstm_model.layers[-1].output

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Dense, BatchNormalization, Dropout, LSTM, Input, Concatenate

combined_output = Concatenate()([lstm_output, dnn_output])

# Output layer
output = Dense(labels.shape[1], activation='softmax')(combined_output)

# Define the combined model
combined_model1 = Model(inputs=[lstm_model.input, model.input], outputs=output)

# Compile the model
combined_model1.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Display model summary
combined_model1.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  dense_4_input (InputLayer)     [(None, 115)]        0           []
#
#  dense_4 (Dense)                (None, 128)          14848       ['dense_4_input[0][0]']
#
#  batch_normalization (BatchNorm  (None, 128)         512         ['dense_4[0][0]']
#  alization)
#
#  lstm_input (InputLayer)        [(None, 115, 1)]     0           []
#
#  dropout_3 (Dropout)            (None, 128)          0           ['batch_normalization[0][0]']
#
#  lstm (LSTM)                    (None, 115, 32)      4352        ['lstm_input[0][0]']
#
#  dense_5 (Dense)                (None, 256)          33024       ['dropout_3[0][0]']
#
#  dropout (Dropout)              (None, 115, 32)      0           ['lstm[0][0]']
#
#  batch_normalization_1 (BatchNo  (None, 256)         1024        ['dense_5[0][0]']
#  rmalization)
#
#  lstm_1 (LSTM)                  (None, 115, 64)      24832       ['dropout[0][0]']
#
#  dropout_4 (Dropout)            (None, 256)          0           ['batch_normalization_1[0][0]']
#
#  dropout_1 (Dropout)            (None, 115, 64)      0           ['lstm_1[0][0]']
#
#  dense_6 (Dense)                (None, 128)          32896       ['dropout_4[0][0]']
#
#  lstm_2 (LSTM)                  (None, 32)           12416       ['dropout_1[0][0]']
#
#  batch_normalization_2 (BatchNo  (None, 128)         512         ['dense_6[0][0]']
#  rmalization)
#
#  dropout_2 (Dropout)            (None, 32)           0           ['lstm_2[0][0]']
#
#  dropout_5 (Dropout)            (None, 128)          0           ['batch_normalization_2[0][0]']
#
#  dense (Dense)                  (None, 3)            99          ['dropout_2[0][0]']
#
#  dense_7 (Dense)                (None, 3)            387         ['dropout_5[0][0]']
#
#  concatenate_1 (Concatenate)    (None, 6)            0           ['dense[0][0]',
#                                                                   'dense_7[0][0]']
#
#  dense_10 (Dense)               (None, 3)            21          ['concatenate_1[0][0]']
#
# ==================================================================================================
# Total params: 124,923
# Trainable params: 123,899
# Non-trainable params: 1,024
# __________________________________________________________________________________________________

# %%
# Set up ModelCheckpoint callback to save model weights during training
model_checkpoint = ModelCheckpoint('combined_model_checkpoint.h5', monitor='val_loss', save_best_only=True)

# Train the model
history = combined_model.fit([x_train, x_train], y_train, validation_data=([x_test, x_test], y_test), epochs=10, batch_size=32, callbacks=[model_checkpoint])

# %%
combined_model1.load_weights('combined_model_checkpoint.h5')

# %%
test_loss, test_accuracy = combined_model1.evaluate([x_test, x_test], y_test)
print(f"Test Loss: {test_loss}, Test Accuracy: {test_accuracy}")
# Out:
# 11036/11036 [==============================] - 346s 31ms/step - loss: 0.0015 - accuracy: 0.9997
# Test Loss: 0.001468061818741262, Test Accuracy: 0.9996941685676575

# %%
from sklearn.metrics import precision_score, recall_score, f1_score , confusion_matrix


y_pred = combined_model1.predict([x_test, x_test])

# Convert one-hot encoded predictions and true labels to class labels
y_pred_classes = np.argmax(y_pred, axis=1)
y_true_classes = np.argmax(y_test, axis=1)

# Calculate precision, recall, and F1 score
precision = precision_score(y_true_classes, y_pred_classes, average='weighted')
recall = recall_score(y_true_classes, y_pred_classes, average='weighted')
f1 = f1_score(y_true_classes, y_pred_classes, average='weighted')
conf_matrix = confusion_matrix(y_true_classes, y_pred_classes)

print(f"Precision: {precision}")
print(f"Recall: {recall}")
print(f"F1 Score: {f1}")
print(conf_matrix)
# Out:
# 11036/11036 [==============================] - 654s 59ms/step
# Precision: 0.9996913340505241
# Recall: 0.9996913318041515
# F1 Score: 0.9996913258529452
# [[ 27877     42      5]
#  [    35 141883      1]
#  [     4     22 183261]]

# %% [markdown]
# # LSTM-PNN

# %%
lstm_output = lstm_model.layers[-1].output
pnn_output = progressive_nn.layers[-1].output

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Dense, BatchNormalization, Dropout, LSTM, Input, Concatenate


concatenated = Concatenate()([lstm_output, pnn_output])

# Output layer
output = Dense(labels.shape[1], activation='softmax')(concatenated)

# Create the hybrid model
hybrid_model1 = Model(inputs=[lstm_model.input, progressive_nn.input], outputs=output)

# Compile the model
hybrid_model1.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# Display model summary
hybrid_model1.summary()
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  lstm_input (InputLayer)        [(None, 115, 1)]     0           []
#
#  lstm (LSTM)                    (None, 115, 32)      4352        ['lstm_input[0][0]']
#
#  dropout (Dropout)              (None, 115, 32)      0           ['lstm[0][0]']
#
#  lstm_1 (LSTM)                  (None, 115, 64)      24832       ['dropout[0][0]']
#
#  dropout_1 (Dropout)            (None, 115, 64)      0           ['lstm_1[0][0]']
#
#  dense_1_input (InputLayer)     [(None, 115)]        0           []
#
#  lstm_2 (LSTM)                  (None, 32)           12416       ['dropout_1[0][0]']
#
#  dense_1 (Dense)                (None, 64)           7424        ['dense_1_input[0][0]']
#
#  dropout_2 (Dropout)            (None, 32)           0           ['lstm_2[0][0]']
#
#  dense_2 (Dense)                (None, 128)          8320        ['dense_1[0][0]']
#
#  dense (Dense)                  (None, 3)            99          ['dropout_2[0][0]']
#
#  dense_3 (Dense)                (None, 3)            387         ['dense_2[0][0]']
#
#  concatenate_2 (Concatenate)    (None, 6)            0           ['dense[0][0]',
#                                                                   'dense_3[0][0]']
#
#  dense_11 (Dense)               (None, 3)            21          ['concatenate_2[0][0]']
#
# ==================================================================================================
# Total params: 57,851
# Trainable params: 57,851
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
model_checkpoint = ModelCheckpoint('hybrid_model1_checkpoint.h5', monitor='val_loss', save_best_only=True)

# Train the model
history = hybrid_model1.fit([x_train, x_train], y_train, validation_data=([x_test, x_test], y_test), epochs=5, batch_size=32, callbacks=[model_checkpoint])

# %%
hybrid_model1.load_weights('hybrid_model1_checkpoint.h5')

# %%
test_loss, test_accuracy = hybrid_model1.evaluate([x_test, x_test], y_test)
print(f"Test Loss: {test_loss}, Test Accuracy: {test_accuracy}")
# Out:
# 11036/11036 [==============================] - 304s 28ms/step - loss: 0.0028 - accuracy: 0.9996
# Test Loss: 0.0027555404230952263, Test Accuracy: 0.9995638728141785

# %%
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Concatenate, Dense

# %%
from sklearn.metrics import precision_score, recall_score, f1_score , confusion_matrix


y_pred = hybrid_model1.predict([x_test, x_test])

# Convert one-hot encoded predictions and true labels to class labels
y_pred_classes = np.argmax(y_pred, axis=1)
y_true_classes = np.argmax(y_test, axis=1)

# Calculate precision, recall, and F1 score
precision = precision_score(y_true_classes, y_pred_classes, average='weighted')
recall = recall_score(y_true_classes, y_pred_classes, average='weighted')
f1 = f1_score(y_true_classes, y_pred_classes, average='weighted')
conf_matrix = confusion_matrix(y_true_classes, y_pred_classes)

print(f"Precision: {precision}")
print(f"Recall: {recall}")
print(f"F1 Score: {f1}")
print(conf_matrix)
# Out:
# 11036/11036 [==============================] - 549s 50ms/step
# Precision: 0.999600641574129
# Recall: 0.9996007136182142
# F1 Score: 0.9996006503105789
# [[ 27856     50     18]
#  [    31 141876     12]
#  [     7     23 183257]]

# %% [markdown]
# # LSTM-DNN-PNN

# %%
# Make predictions using each model
dnn_predictions = model.predict(x_test)
pnn_predictions = progressive_nn.predict(x_test)
lstm_predictions = lstm_model.predict(x_test)


combined_features = np.concatenate((dnn_predictions, pnn_predictions, lstm_predictions), axis=1)

# Define a simple neural network as the meta-model
meta_model = Sequential([
    Dense(64, activation='relu', input_shape=(combined_features.shape[1],)),
    Dense(32, activation='relu'),
    Dense(labels.shape[1], activation='softmax')
])

# Compile the meta-model
meta_model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

meta_model.summary()
# Out:
# 11036/11036 [==============================] - 28s 2ms/step
# 11036/11036 [==============================] - 18s 2ms/step
# 11036/11036 [==============================] - 661s 60ms/step
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_12 (Dense)            (None, 64)                640
#
#  dense_13 (Dense)            (None, 32)                2080
#
#  dense_14 (Dense)            (None, 3)                 99
#
# =================================================================
# Total params: 2,819
# Trainable params: 2,819
# Non-trainable params: 0
# _________________________________________________________________

# %%
model_checkpoint = ModelCheckpoint('meta_model_checkpoint.h5', monitor='val_loss', save_best_only=True)


# Train the meta-model on the combined features
meta_model.fit(combined_features, y_test, epochs=10, batch_size=32, validation_split=0.2)
# Out:
# Epoch 1/10
# 8829/8829 [==============================] - 6s 618us/step - loss: 0.0073 - accuracy: 0.9987 - val_loss: 0.0017 - val_accuracy: 0.9995
# Epoch 2/10
# 8829/8829 [==============================] - 6s 630us/step - loss: 0.0018 - accuracy: 0.9996 - val_loss: 0.0014 - val_accuracy: 0.9996
# Epoch 3/10
# 8829/8829 [==============================] - 6s 630us/step - loss: 0.0018 - accuracy: 0.9996 - val_loss: 0.0013 - val_accuracy: 0.9997
# Epoch 4/10
# 8829/8829 [==============================] - 5s 572us/step - loss: 0.0017 - accuracy: 0.9996 - val_loss: 0.0015 - val_accuracy: 0.9996
# Epoch 5/10
# 8829/8829 [==============================] - 5s 607us/step - loss: 0.0017 - accuracy: 0.9996 - val_loss: 0.0012 - val_accuracy: 0.9997
# Epoch 6/10
# 8829/8829 [==============================] - 5s 591us/step - loss: 0.0017 - accuracy: 0.9996 - val_loss: 0.0011 - val_accuracy: 0.9997
# Epoch 7/10
# 8829/8829 [==============================] - 6s 645us/step - loss: 0.0016 - accuracy: 0.9996 - val_loss: 0.0013 - val_accuracy: 0.9996
# Epoch 8/10
# 8829/8829 [==============================] - 5s 611us/step - loss: 0.0016 - accuracy: 0.9996 - val_loss: 0.0011 - val_accuracy: 0.9996
# Epoch 9/10
# 8829/8829 [==============================] - 6s 624us/step - loss: 0.0016 - accuracy: 0.9996 - val_loss: 0.0012 - val_accuracy: 0.9996
# Epoch 10/10
# 8829/8829 [==============================] - 5s 592us/step - loss: 0.0016 - accuracy: 0.9996 - val_loss: 0.0015 - val_accuracy: 0.9996

# %%
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score

# Make predictions using the hybrid model
predictions = meta_model.predict(combined_features)
predicted_labels = np.argmax(predictions, axis=1)

# Convert true labels to class labels
true_labels = np.argmax(y_test, axis=1)

# Calculate accuracy
accuracy = accuracy_score(true_labels, predicted_labels)

# Calculate F1-score
f1 = f1_score(true_labels, predicted_labels, average='weighted')

# Calculate precision
precision = precision_score(true_labels, predicted_labels, average='weighted')

# Calculate recall
recall = recall_score(true_labels, predicted_labels, average='weighted')

print("Accuracy:", accuracy)
print("F1-score:", f1)
print("Precision:", precision)
print("Recall:", recall)
# Out:
# Accuracy: 0.9996375272562512
# F1-score: 0.999637502599554
# Precision: 0.9996375175361529
# Recall: 0.9996375272562512

# %%
from keras.layers import Activation
import keras.backend as K

def swish(x):
    return x * K.sigmoid(x)

# Make predictions using each model
dnn_predictions = model.predict(x_test)
pnn_predictions = progressive_nn.predict(x_test)
lstm_predictions = lstm_model.predict(x_test)

combined_features = np.concatenate((dnn_predictions, pnn_predictions, lstm_predictions), axis=1)

# Define a simple neural network as the meta-model
meta_model11 = Sequential([
    Dense(64, activation=LeakyReLU(alpha=0.1), input_shape=(combined_features.shape[1],)),
    Dense(32, activation=LeakyReLU(alpha=0.1)),
    Dense(labels.shape[1]),
    Activation(swish)
])

# Compile the meta-model
meta_model11.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

meta_model11.summary()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_18 (Dense)            (None, 64)                640
#
#  dense_19 (Dense)            (None, 32)                2080
#
#  dense_20 (Dense)            (None, 3)                 99
#
#  activation_1 (Activation)   (None, 3)                 0
#
# =================================================================
# Total params: 2,819
# Trainable params: 2,819
# Non-trainable params: 0
# _________________________________________________________________

# %%
model_checkpoint = ModelCheckpoint('meta_model_checkpoint.h5', monitor='val_loss', save_best_only=True)


# Train the meta-model on the combined features
meta_model11.fit(combined_features, y_test, epochs=10, batch_size=32, validation_split=0.2)
# Out:
# Epoch 1/10
# 8829/8829 [==============================] - 7s 800us/step - loss: 6.9694 - accuracy: 0.5542 - val_loss: 7.7025 - val_accuracy: 0.5221
# Epoch 2/10
# 8829/8829 [==============================] - 6s 736us/step - loss: 7.7453 - accuracy: 0.5195 - val_loss: 7.7025 - val_accuracy: 0.5221
# Epoch 3/10
# 8829/8829 [==============================] - 7s 763us/step - loss: 7.7453 - accuracy: 0.5195 - val_loss: 7.7025 - val_accuracy: 0.5221
# Epoch 4/10
# 8829/8829 [==============================] - 7s 798us/step - loss: 7.7453 - accuracy: 0.5195 - val_loss: 7.7025 - val_accuracy: 0.5221
# Epoch 5/10
# 8829/8829 [==============================] - 7s 745us/step - loss: 7.7453 - accuracy: 0.5195 - val_loss: 7.7025 - val_accuracy: 0.5221
# Epoch 6/10
# 8829/8829 [==============================] - 7s 755us/step - loss: 7.7453 - accuracy: 0.5195 - val_loss: 7.7025 - val_accuracy: 0.5221
# Epoch 7/10
# 8829/8829 [==============================] - 7s 768us/step - loss: 7.7453 - accuracy: 0.5195 - val_loss: 7.7025 - val_accuracy: 0.5221
# Epoch 8/10
# 8829/8829 [==============================] - 6s 714us/step - loss: 7.7453 - accuracy: 0.5195 - val_loss: 7.7025 - val_accuracy: 0.5221
# Epoch 9/10
# 8829/8829 [==============================] - 7s 773us/step - loss: 7.7453 - accuracy: 0.5195 - val_loss: 7.7025 - val_accuracy: 0.5221
# Epoch 10/10
# 8829/8829 [==============================] - 6s 731us/step - loss: 7.7453 - accuracy: 0.5195 - val_loss: 7.7025 - val_accuracy: 0.5221

# %%
from tensorflow.keras.activations import swish

# Make predictions using each model
dnn_predictions = model.predict(x_test)
pnn_predictions = progressive_nn.predict(x_test)
lstm_predictions = lstm_model.predict(x_test)

combined_features = np.concatenate((dnn_predictions, pnn_predictions, lstm_predictions), axis=1)

# Define a simple neural network as the meta-model with Swish activation
meta_model_swish = Sequential([
    Dense(64, activation='relu', input_shape=(combined_features.shape[1],)),
    Dense(32, activation='relu'),
    Dense(labels.shape[1], activation=swish)  # Using Swish activation
])

# Compile the meta-model with Swish activation
meta_model_swish.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

meta_model_swish.summary()
# Out:
# Model: "sequential_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_24 (Dense)            (None, 64)                640
#
#  dense_25 (Dense)            (None, 32)                2080
#
#  dense_26 (Dense)            (None, 3)                 99
#
# =================================================================
# Total params: 2,819
# Trainable params: 2,819
# Non-trainable params: 0
# _________________________________________________________________

# %%
model_checkpoint = ModelCheckpoint('meta_model_checkpoint.h5', monitor='val_loss', save_best_only=True)


# Train the meta-model on the combined features
meta_model_swish.fit(combined_features, y_test, epochs=10, batch_size=32, validation_split=0.2)
# Out:
# Epoch 1/10
# 8829/8829 [==============================] - 7s 774us/step - loss: 9.5933 - accuracy: 0.3679 - val_loss: 9.6445 - val_accuracy: 0.3989
# Epoch 2/10
# 8829/8829 [==============================] - 7s 750us/step - loss: 9.6015 - accuracy: 0.4014 - val_loss: 9.6445 - val_accuracy: 0.3989
# Epoch 3/10
# 8829/8829 [==============================] - 7s 747us/step - loss: 9.6015 - accuracy: 0.4014 - val_loss: 9.6445 - val_accuracy: 0.3989
# Epoch 4/10
# 8829/8829 [==============================] - 7s 770us/step - loss: 9.6015 - accuracy: 0.4014 - val_loss: 9.6445 - val_accuracy: 0.3989
# Epoch 5/10
# 8829/8829 [==============================] - 7s 773us/step - loss: 9.6015 - accuracy: 0.4014 - val_loss: 9.6445 - val_accuracy: 0.3989
# Epoch 6/10
# 8829/8829 [==============================] - 6s 700us/step - loss: 9.6015 - accuracy: 0.4014 - val_loss: 9.6445 - val_accuracy: 0.3989
# Epoch 7/10
# 8829/8829 [==============================] - 6s 730us/step - loss: 9.6015 - accuracy: 0.4014 - val_loss: 9.6445 - val_accuracy: 0.3989
# Epoch 8/10
# 8829/8829 [==============================] - 7s 757us/step - loss: 9.6015 - accuracy: 0.4014 - val_loss: 9.6445 - val_accuracy: 0.3989
# Epoch 9/10
# 8829/8829 [==============================] - 6s 702us/step - loss: 9.6015 - accuracy: 0.4014 - val_loss: 9.6445 - val_accuracy: 0.3989
# Epoch 10/10
# 8829/8829 [==============================] - 6s 719us/step - loss: 9.6015 - accuracy: 0.4014 - val_loss: 9.6445 - val_accuracy: 0.3989

# %% [markdown]
# # LSTM-DNN-PNN

# %%
lstm_output = lstm_model.layers[-1].output
dnn_output = model.layers[-1].output
pnn_output = progressive_nn.layers[-1].output

# %%
# Concatenate outputs
combined_output = concatenate([lstm_output, dnn_output, pnn_output])

# Additional Layers 
combined_output = Dense(128, activation='relu')(combined_output)
combined_output = Dense(3, activation='softmax')(combined_output)


# Create combined model
combined_model3 = tf.keras.Model(inputs=[lstm_model.input, progressive_nn.input,model.input], outputs=combined_output)

# Optionally, compile the model
combined_model3.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Display model summary
combined_model3.summary()
# Out:
# Model: "model_4"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  dense_4_input (InputLayer)     [(None, 115)]        0           []
#
#  dense_4 (Dense)                (None, 128)          14848       ['dense_4_input[0][0]']
#
#  batch_normalization (BatchNorm  (None, 128)         512         ['dense_4[0][0]']
#  alization)
#
#  lstm_input (InputLayer)        [(None, 115, 1)]     0           []
#
#  dropout_3 (Dropout)            (None, 128)          0           ['batch_normalization[0][0]']
#
#  lstm (LSTM)                    (None, 115, 32)      4352        ['lstm_input[0][0]']
#
#  dense_5 (Dense)                (None, 256)          33024       ['dropout_3[0][0]']
#
#  dropout (Dropout)              (None, 115, 32)      0           ['lstm[0][0]']
#
#  batch_normalization_1 (BatchNo  (None, 256)         1024        ['dense_5[0][0]']
#  rmalization)
#
#  lstm_1 (LSTM)                  (None, 115, 64)      24832       ['dropout[0][0]']
#
#  dropout_4 (Dropout)            (None, 256)          0           ['batch_normalization_1[0][0]']
#
#  dropout_1 (Dropout)            (None, 115, 64)      0           ['lstm_1[0][0]']
#
#  dense_6 (Dense)                (None, 128)          32896       ['dropout_4[0][0]']
#
#  dense_1_input (InputLayer)     [(None, 115)]        0           []
#
#  lstm_2 (LSTM)                  (None, 32)           12416       ['dropout_1[0][0]']
#
#  batch_normalization_2 (BatchNo  (None, 128)         512         ['dense_6[0][0]']
#  rmalization)
#
#  dense_1 (Dense)                (None, 64)           7424        ['dense_1_input[0][0]']
#
#  dropout_2 (Dropout)            (None, 32)           0           ['lstm_2[0][0]']
#
#  dropout_5 (Dropout)            (None, 128)          0           ['batch_normalization_2[0][0]']
#
#  dense_2 (Dense)                (None, 128)          8320        ['dense_1[0][0]']
#
#  dense (Dense)                  (None, 3)            99          ['dropout_2[0][0]']
#
#  dense_7 (Dense)                (None, 3)            387         ['dropout_5[0][0]']
#
#  dense_3 (Dense)                (None, 3)            387         ['dense_2[0][0]']
#
#  concatenate_4 (Concatenate)    (None, 9)            0           ['dense[0][0]',
#                                                                   'dense_7[0][0]',
#                                                                   'dense_3[0][0]']
#
#  dense_13 (Dense)               (None, 128)          1280        ['concatenate_4[0][0]']
#
#  dense_14 (Dense)               (None, 3)            387         ['dense_13[0][0]']
#
# ==================================================================================================
# Total params: 142,700
# Trainable params: 141,676
# Non-trainable params: 1,024
# __________________________________________________________________________________________________

# %%
# Set up ModelCheckpoint callback to save model weights during training
model_checkpoint = ModelCheckpoint('combined_model3_checkpoint.h5', monitor='val_loss', save_best_only=True)

# Train the model
history=combined_model3.fit([x_train, x_train, x_train], y_train, 
                   batch_size=32, 
                   epochs=5, 
                   validation_data=([x_test, x_test, x_test], y_test))
# Out:
# Epoch 1/5
# 44142/44142 [==============================] - 11720s 265ms/step - loss: 0.0034 - accuracy: 0.9994 - val_loss: 0.0029 - val_accuracy: 0.9995
# Epoch 2/5
#  8729/44142 [====>.........................] - ETA: 18:50:36 - loss: 0.0025 - accuracy: 0.9995
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [32], in <module>
#       2 model_checkpoint = ModelCheckpoint('combined_model3_checkpoint.h5', monitor='val_loss', save_best_only=True)
#       4 # Train the model
# ----> 5 history=combined_model3.fit([x_train, x_train, x_train], y_train,
#       6                    batch_size=32,
#       7                    epochs=5,
#       8                    validation_data=([x_test, x_test, x_test], y_test))
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\keras\utils\traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\keras\engine\training.py:1685, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1677 with tf.profiler.experimental.Trace(
#    1678     "train",
#    1679     epoch_num=epoch,
#    (...)
#    1682     _r=1,
#    1683 ):
#    1684     callbacks.on_train_batch_begin(step)
# -> 1685     tmp_logs = self.train_function(iterator)
#    1686     if data_handler.should_sync:
#    1687         context.async_wait()
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py:894, in Function.__call__(self, *args, **kwds)
#     891 compiler = "xla" if self._jit_compile else "nonXla"
#     893 with OptionalXlaContext(self._jit_compile):
# --> 894   result = self._call(*args, **kwds)
#     896 new_tracing_count = self.experimental_get_tracing_count()
#     897 without_tracing = (tracing_count == new_tracing_count)
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py:926, in Function._call(self, *args, **kwds)
#     923   self._lock.release()
#     924   # In this case we have created variables on the first call, so we run the
#     925   # defunned version which is guaranteed to never create variables.
# --> 926   return self._no_variable_creation_fn(*args, **kwds)  # pylint: disable=not-callable
#     927 elif self._variable_creation_fn is not None:
#     928   # Release the lock early so that multiple threads can perform the call
#     929   # in parallel.
#     930   self._lock.release()
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\tensorflow\python\eager\polymorphic_function\tracing_compiler.py:143, in TracingCompiler.__call__(self, *args, **kwargs)
#     140 with self._lock:
#     141   (concrete_function,
#     142    filtered_flat_args) = self._maybe_define_function(args, kwargs)
# --> 143 return concrete_function._call_flat(
#     144     filtered_flat_args, captured_inputs=concrete_function.captured_inputs)
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\tensorflow\python\eager\polymorphic_function\monomorphic_function.py:1757, in ConcreteFunction._call_flat(self, args, captured_inputs, cancellation_manager)
#    1753 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1754 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1755     and executing_eagerly):
#    1756   # No tape is watching; skip to running the function.
# -> 1757   return self._build_call_outputs(self._inference_function.call(
#    1758       ctx, args, cancellation_manager=cancellation_manager))
#    1759 forward_backward = self._select_forward_and_backward_functions(
#    1760     args,
#    1761     possible_gradient_type,
#    1762     executing_eagerly)
#    1763 forward_function, args_with_tangents = forward_backward.forward()
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\tensorflow\python\eager\polymorphic_function\monomorphic_function.py:381, in _EagerDefinedFunction.call(self, ctx, args, cancellation_manager)
#     379 with _InterpolateFunctionError(self):
#     380   if cancellation_manager is None:
# --> 381     outputs = execute.execute(
#     382         str(self.signature.name),
#     383         num_outputs=self._num_outputs,
#     384         inputs=args,
#     385         attrs=attrs,
#     386         ctx=ctx)
#     387   else:
#     388     outputs = execute.execute_with_cancellation(
#     389         str(self.signature.name),
#     390         num_outputs=self._num_outputs,
#    (...)
#     393         ctx=ctx,
#     394         cancellation_manager=cancellation_manager)
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\tensorflow\python\eager\execute.py:52, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      50 try:
#      51   ctx.ensure_initialized()
# ---> 52   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      53                                       inputs, attrs, num_outputs)
#      54 except core._NotOkStatusException as e:
#      55   if name is not None:
#
# KeyboardInterrupt:

# %%
import numpy as np
import matplotlib.pyplot as plt

# Attributes
attributes = ['Precision', 'Recall', 'F1 Score', 'Accuracy']

# Scores for LSTM-DNN
lstm_dnn_scores = [0.9996913340505241, 0.9996913318041515, 0.9996913258529452, 0.9996941685676575]

# Scores for DNN-PNN
dnn_pnn_scores = [0.9996124827532105, 0.9996120408914564, 0.9996121757016008, 0.999612033367157]

# Scores for LSTM-PNN
lstm_pnn_scores = [0.999600641574129, 0.9996007136182142, 0.9996006503105789, 0.9995638728141785]

# Combine scores for all models
all_scores = np.array([lstm_dnn_scores, dnn_pnn_scores, lstm_pnn_scores])

# Determine the start and end of y-axis range
start_y = np.min(all_scores) - 0.0005
end_y = np.max(all_scores) + 0.0005

# Set the width of the bars
bar_width = 0.2

# Set the position of the bars on the x-axis
r1 = np.arange(len(attributes))
r2 = [x + bar_width for x in r1]
r3 = [x + 2 * bar_width for x in r1]

# Create the grouped bar plot with grey shades
plt.bar(r1, lstm_dnn_scores, color=(0.1, 0.2, 0.6), width=bar_width, edgecolor='grey', label='LSTM-DNN')
plt.bar(r2, dnn_pnn_scores, color=(0.2, 0.6, 0.2), width=bar_width, edgecolor='grey', label='DNN-PNN')
plt.bar(r3, lstm_pnn_scores, color=(0.6, 0.2, 0.2), width=bar_width, edgecolor='grey', label='LSTM-PNN')

# Add labels and title
plt.xlabel('Attributes', fontweight='bold')
plt.ylabel('Scores', fontweight='bold')
plt.title('Comparison of Attributes (LSTM-DNN, DNN-PNN, LSTM-PNN)')

# Add x-axis tick labels
plt.xticks([r + bar_width for r in range(len(attributes))], attributes)

# Set y-axis range
plt.ylim(start_y, end_y)

# Show plot
plt.legend()
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %%
import matplotlib.pyplot as plt

# Define activation functions and their corresponding accuracy values
activation_functions = ['ReLU/softmax', 'LeakyReLU/Swish']
accuracy_values = [99.96, 52.26]  # Replace these values with your actual accuracy values

# Plotting the bar plot
plt.bar(activation_functions, accuracy_values, color=['blue', 'orange'])
plt.xlabel('Activation Function')
plt.ylabel('Accuracy (%)')
plt.title('Comparison of Accuracy for LSTM-DNN-PNN Hybrid Model')

# Add annotations to the bars
for i in range(len(activation_functions)):
    plt.text(i, accuracy_values[i] + 1, f'{accuracy_values[i]:.2f}', ha='center')

plt.ylim(min(accuracy_values) - 10, max(accuracy_values) + 10)  # Adjust y-axis range
plt.show()

# %%
from IPython.display import Markdown, display

# Create the table data as a list of lists
table_data = [
    ['LSTM-DNN-PNN', '0.9996375272562512', '0.9996375175361529', '0.9996375272562512', '0.999637502599554'],
    ['LSTM-DNN', '0.9997941685676575', '0.9996913340505241', '0.9996913318041515', '0.9996913258529452'],
    ['DNN-PNN', '0.999612033367157', '0.9996124827532105', '0.9996120408914564', '0.9996121757016008'],
    ['LSTM-PNN', '0.9995638728141785', '0.999600641574129', '0.9996007136182142', '0.9996006503105789']
]

# Create the table markdown
table_markdown = '|'.join(['{:30}'.format(header) for header in ['Model', 'Accuracy', 'Precision', 'Recall', 'F1 Score']])
table_markdown += '\n' + '|'.join(['-' * 30] * 5)

for row in table_data:
    table_markdown += '\n' + '|'.join(['{:30}'.format(cell) for cell in row])

# Display the table in Jupyter Notebook
display(Markdown("<style>table {font-size: 15px}</style>"))
display(Markdown(table_markdown))
# Out:
# <style>table {font-size: 15px}</style>
# Model                         |Accuracy                      |Precision                     |Recall                        |F1 Score
# ------------------------------|------------------------------|------------------------------|------------------------------|------------------------------
# LSTM-DNN-PNN                  |0.9996375272562512            |0.9996375175361529            |0.9996375272562512            |0.999637502599554
# LSTM-DNN                      |0.9997941685676575            |0.9996913340505241            |0.9996913318041515            |0.9996913258529452
# DNN-PNN                       |0.999612033367157             |0.9996124827532105            |0.9996120408914564            |0.9996121757016008
# LSTM-PNN                      |0.9995638728141785            |0.999600641574129             |0.9996007136182142            |0.9996006503105789

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Provided confusion matrix
cm = np.array([[27856, 50, 18],
               [31, 141876, 12],
               [7, 23, 183257]])

# Class labels
labels = ['Bening', 'Mirai', 'Gafgyt']

# Normalize the confusion matrix
#cm_normalized = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]

# Plot confusion matrix
plt.figure(figsize=(10, 7))
sns.set(font_scale=1.2)  # Adjust font size
sns.heatmap(cm , annot=True, cmap='Blues', fmt='.2f', xticklabels=labels, yticklabels=labels, vmin=0, vmax=6000)
plt.xlabel('Predicted labels')
plt.ylabel('True labels')
plt.title('Confusion Matrix')
plt.show()

# %%
from IPython.display import Markdown, display

# Define data for each model
model_data = {
    'LSTM-DNN-PNN': {
        'Accuracy': 0.9996375272562512,
        'Precision': 0.9996375175361529,
        'Recall': 0.9996375272562512,
        'F1 Score': 0.999637502599554
    },
    'LSTM-DNN': {
        'Accuracy': 0.9997941685676575,
        'Precision': 0.9996913340505241,
        'Recall': 0.9996913318041515,
        'F1 Score': 0.9996913258529452
    },
    'DNN-PNN': {
        'Accuracy': 0.999612033367157,
        'Precision': 0.9996124827532105,
        'Recall': 0.9996120408914564,
        'F1 Score': 0.9996121757016008
    },
    'LSTM-PNN': {
        'Accuracy': 0.9995638728141785,
        'Precision': 0.999600641574129,
        'Recall': 0.9996007136182142,
        'F1 Score': 0.9996006503105789
    }
}

# Display individual Markdown tables for each model horizontally
table_markdown = ""
for model, data in model_data.items():
    table_markdown += f"### {model}\n"
    table_markdown += "|Performance Evaluation|Value|\n"
    table_markdown += "|----------------------|-----|\n"
    for perf_eval, value in data.items():
        table_markdown += f"|{perf_eval:<20}|{value:<15.5f}|\n"
    table_markdown += "\n"

display(Markdown(table_markdown))
# Out:
# ### LSTM-DNN-PNN
# |Performance Evaluation|Value|
# |----------------------|-----|
# |Accuracy            |0.99964        |
# |Precision           |0.99964        |
# |Recall              |0.99964        |
# |F1 Score            |0.99964        |
#
# ### LSTM-DNN
# |Performance Evaluation|Value|
# |----------------------|-----|
# |Accuracy            |0.99979        |
# |Precision           |0.99969        |
# |Recall              |0.99969        |
# |F1 Score            |0.99969        |
#
# ### DNN-PNN
# |Performance Evaluation|Value|
# |----------------------|-----|
# |Accuracy            |0.99961        |
# |Precision           |0.99961        |
# |Recall              |0.99961        |
# |F1 Score            |0.99961        |
#
# ### LSTM-PNN
# |Performance Evaluation|Value|
# |----------------------|-----|
# |Accuracy            |0.99956        |
# |Precision           |0.99960        |
# |Recall              |0.99960        |
# |F1 Score            |0.99960        |
